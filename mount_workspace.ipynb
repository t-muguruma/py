# %%
import os
import sys

# GitHubリポジトリのパス
REPO_URL = "https://github.com/t-muguruma/py.git"
REPO_DIR = "/content/py"

# まだクローンされていなければクローンする
if not os.path.exists(REPO_DIR):
    print(f"Cloning repository from {REPO_URL}...")
    # !git clone $REPO_URL $REPO_DIR
else:
    print("Repository exists. Pulling latest changes...")
    # !git -C $REPO_DIR pull

# Pythonがスクリプトを見つけられるようにパスを追加
if REPO_DIR not in sys.path:
    sys.path.append(REPO_DIR)

print("✅ Setup complete. Ready to mount.")
# Out:
# Cloning repository from https://github.com/t-muguruma/py
# Cloning into '/content/py'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# fatal: could not read Username for 'https://github.com': No such device or address
# ✅ Setup complete. Ready to mount.

# %%
try:
    import my_garmin_common
    print("Attempting to mount Google Drive using my_garmin_common...")
    my_garmin_common.mount_drive()
except ModuleNotFoundError:
    print("⚠️ my_garmin_common not found (Clone failed?).")
    print("Falling back to direct mount...")
    from google.colab import drive
    import os
    if not os.path.exists('/content/drive'):
        drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_423/3863545625.py in <cell line: 0>()
# ----> 1 import my_garmin_common
#       2
#       3 print("Attempting to mount Google Drive...")
#       4 my_garmin_common.mount_drive()
#       5 print("✅ Mount command finished. Check file explorer for '/content/drive'.")
#
# ModuleNotFoundError: No module named 'my_garmin_common'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
